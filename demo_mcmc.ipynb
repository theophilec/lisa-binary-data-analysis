# %%
import model
import analyse
import mcmc
import numpy as np
import time
import noise
import matplotlib.pyplot as plt

# %% [markdown]
# # Simulation parametrization

# %%
t = np.arange(0, 365.25*24*60*60, 150.) # 1 year with 1 point per 15 seconds (or 15O seconds)
omega = 2*np.pi*1.000e-3
omega_dot= 0
beta = 0.474
lamb = 5.199
h0 = 1.75*1.0e-22 * 2 * 2 # multiply by 4 for scale... why ? (issue opened) e-22 enlevé
phi0 = 0
i = 0
psi = 0

# %%
n = 200

start = [omega, omega_dot, 0.347, 5.1, h0, phi0, i, psi]

fixed = [1, 1, 0, 0, 1, 1, 1, 1]
jump_size = [1, 1, 0.08, 0.05, 0, 1, 1, 1]

# %% [markdown]
# # Waveform generation

# %%
modele = model.Model(t, omega, omega_dot, beta, lamb, h0, phi0, i, psi)
modele1 = model.Model(t, omega, omega_dot, beta, lamb, h0, phi0, i, psi)
modele.one_off_calculations()
modele.calculate_phi_mod()
modele.update_all_signals()
modele1.one_off_calculations()
modele1.calculate_phi_mod()
modele1.update_all_signals()
modele.update_frequency_array()
ana = analyse.Analyse(modele, modele1)
# Out:
# noise.py:24: RuntimeWarning: divide by zero encountered in divide
#   SAccelerationNoise = 6.00e-48*(1+1.e-4/f)/(f*f)
# noise.py:27: RuntimeWarning: invalid value encountered in multiply
#   Sn = 16.0*np.sin(phiL)*np.sin(phiL)*(SOpticalNoise + (3.0+np.cos(2.0*phiL))*SAccelerationNoise)

# %%
ana.likelihood(False)
# Out:
# 52.34284756599496

# %% [markdown]
# # MCMC

# %%
ana.launch_mcmc(n, start, fixed, jump_size)
# Out:
# Beginning MCMC optimization for 200 steps.
# Iteration number 1
# New iteration
# Jump in lamba is 0.0852501385658803
# 0.299173145539079
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 2.99173146e-01 5.18525014e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.214463414132354
# Old likelihood is : 50.91367917595311
# Data lambda is : 5.199
# Old model lambda is : 5.1
# New model lambda is : 5.18525013856588
# Data beta is : 0.474
# Old model beta is : 0.347
# New model beta is : 0.299173145539079
# Le delta de likelihood vaut : -0.69921576182076
# Le a tiré : 0.0584816913667
# Le ratio de likelihood : 0.4969748976931307
# True
# Jump accepted.
#
#
# Iteration number 2
# New iteration
# Jump in lamba is -0.01633578055797133
# 0.3622146650158943
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.62214665e-01 5.16891436e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.59070545610132
# Old likelihood is : 50.214463414132354
# Data lambda is : 5.199
# Old model lambda is : 5.18525013856588
# New model lambda is : 5.168914358007909
# Data beta is : 0.474
# Old model beta is : 0.299173145539079
# New model beta is : 0.3622146650158943
# Le delta de likelihood vaut : 1.3762420419689647
# Le a tiré : 0.0546591613607
# Le ratio de likelihood : 3.9599921461499874
# True
# Jump accepted.
#
#
# Iteration number 3
# New iteration
# Jump in lamba is 0.03640958919137851
# 0.40062622944103937
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.00626229e-01 5.20532395e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.7826700626264
# Old likelihood is : 51.59070545610132
# Data lambda is : 5.199
# Old model lambda is : 5.168914358007909
# New model lambda is : 5.205323947199287
# Data beta is : 0.474
# Old model beta is : 0.3622146650158943
# New model beta is : 0.40062622944103937
# Le delta de likelihood vaut : 0.19196460652508307
# Le a tiré : 0.75814261918
# Le ratio de likelihood : 1.2116276324937705
# True
# Jump accepted.
#
#
# Iteration number 4
# New iteration
# Jump in lamba is 0.0032918163365282375
# 0.4359547918400255
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.35954792e-01 5.20861576e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.13186678607852
# Old likelihood is : 51.7826700626264
# Data lambda is : 5.199
# Old model lambda is : 5.205323947199287
# New model lambda is : 5.208615763535815
# Data beta is : 0.474
# Old model beta is : 0.40062622944103937
# New model beta is : 0.4359547918400255
# Le delta de likelihood vaut : 0.34919672345211694
# Le a tiré : 0.0711616603083
# Le ratio de likelihood : 1.4179281026179944
# True
# Jump accepted.
#
#
# Iteration number 5
# New iteration
# Jump in lamba is 0.005975317421244847
# 0.3273307156770124
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.27330716e-01 5.21459108e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.22645269815101
# Old likelihood is : 52.13186678607852
# Data lambda is : 5.199
# Old model lambda is : 5.208615763535815
# New model lambda is : 5.21459108095706
# Data beta is : 0.474
# Old model beta is : 0.4359547918400255
# New model beta is : 0.3273307156770124
# Le delta de likelihood vaut : -1.905414087927511
# Le a tiré : 0.481714212757
# Le ratio de likelihood : 0.14876102971995014
# False
# Jump not accepted.
#
#
# Iteration number 6
# New iteration
# Jump in lamba is -0.12308320468415462
# 0.4902356935397178
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.90235694e-01 5.08553256e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.61846561023513
# Old likelihood is : 52.13186678607852
# Data lambda is : 5.199
# Old model lambda is : 5.208615763535815
# New model lambda is : 5.085532558851661
# Data beta is : 0.474
# Old model beta is : 0.4359547918400255
# New model beta is : 0.4902356935397178
# Le delta de likelihood vaut : -2.5134011758433914
# Le a tiré : 0.156658135149
# Le ratio de likelihood : 0.08099230119166842
# False
# Jump not accepted.
#
#
# Iteration number 7
# New iteration
# Jump in lamba is 0.1087469314862609
# 0.49839807174881345
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.98398072e-01 5.31736270e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.149012249794005
# Old likelihood is : 52.13186678607852
# Data lambda is : 5.199
# Old model lambda is : 5.208615763535815
# New model lambda is : 5.317362695022076
# Data beta is : 0.474
# Old model beta is : 0.4359547918400255
# New model beta is : 0.49839807174881345
# Le delta de likelihood vaut : -1.9828545362845134
# Le a tiré : 0.711582437127
# Le ratio de likelihood : 0.13767567564847727
# False
# Jump not accepted.
#
#
# Iteration number 8
# New iteration
# Jump in lamba is -0.05041269268665069
# 0.40694795856223154
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.06947959e-01 5.15820307e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.04241183407033
# Old likelihood is : 52.13186678607852
# Data lambda is : 5.199
# Old model lambda is : 5.208615763535815
# New model lambda is : 5.158203070849164
# Data beta is : 0.474
# Old model beta is : 0.4359547918400255
# New model beta is : 0.40694795856223154
# Le delta de likelihood vaut : -0.08945495200818954
# Le a tiré : 0.210410520192
# Le ratio de likelihood : 0.9144294574071913
# True
# Jump accepted.
#
#
# Iteration number 9
# New iteration
# Jump in lamba is -0.05735341710532374
# 0.479288533489261
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.79288533e-01 5.10084965e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.455729535706155
# Old likelihood is : 52.04241183407033
# Data lambda is : 5.199
# Old model lambda is : 5.158203070849164
# New model lambda is : 5.100849653743841
# Data beta is : 0.474
# Old model beta is : 0.40694795856223154
# New model beta is : 0.479288533489261
# Le delta de likelihood vaut : -1.586682298364174
# Le a tiré : 0.334229945144
# Le ratio de likelihood : 0.20460329963135607
# False
# Jump not accepted.
#
#
# Iteration number 10
# New iteration
# Jump in lamba is 0.05428256443381321
# 0.33840677849198386
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.38406778e-01 5.21248564e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.530213434497085
# Old likelihood is : 52.04241183407033
# Data lambda is : 5.199
# Old model lambda is : 5.158203070849164
# New model lambda is : 5.212485635282977
# Data beta is : 0.474
# Old model beta is : 0.40694795856223154
# New model beta is : 0.33840677849198386
# Le delta de likelihood vaut : -1.5121983995732435
# Le a tiré : 0.123711164786
# Le ratio de likelihood : 0.2204248629917544
# True
# Jump accepted.
#
#
# Iteration number 11
# New iteration
# Jump in lamba is 0.07733146670981111
# 0.3875984562517566
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.87598456e-01 5.28981710e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 48.956494929964805
# Old likelihood is : 50.530213434497085
# Data lambda is : 5.199
# Old model lambda is : 5.212485635282977
# New model lambda is : 5.289817101992789
# Data beta is : 0.474
# Old model beta is : 0.33840677849198386
# New model beta is : 0.3875984562517566
# Le delta de likelihood vaut : -1.5737185045322803
# Le a tiré : 0.449640923292
# Le ratio de likelihood : 0.20727300197140103
# False
# Jump not accepted.
#
#
# Iteration number 12
# New iteration
# Jump in lamba is 0.04577361167691987
# 0.29755254927894786
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 2.97552549e-01 5.25825925e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 47.87914103582844
# Old likelihood is : 50.530213434497085
# Data lambda is : 5.199
# Old model lambda is : 5.212485635282977
# New model lambda is : 5.258259246959898
# Data beta is : 0.474
# Old model beta is : 0.33840677849198386
# New model beta is : 0.29755254927894786
# Le delta de likelihood vaut : -2.6510723986686457
# Le a tiré : 0.465607818756
# Le ratio de likelihood : 0.07057548740490874
# False
# Jump not accepted.
#
#
# Iteration number 13
# New iteration
# Jump in lamba is 0.08052924386498717
# 0.34688356830927036
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.46883568e-01 5.29301488e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 47.64796899833445
# Old likelihood is : 50.530213434497085
# Data lambda is : 5.199
# Old model lambda is : 5.212485635282977
# New model lambda is : 5.2930148791479645
# Data beta is : 0.474
# Old model beta is : 0.33840677849198386
# New model beta is : 0.34688356830927036
# Le delta de likelihood vaut : -2.8822444361626367
# Le a tiré : 0.397671111602
# Le ratio de likelihood : 0.05600891322598409
# False
# Jump not accepted.
#
#
# Iteration number 14
# New iteration
# Jump in lamba is -0.07817160622012016
# 0.2561983803407664
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 2.56198380e-01 5.13431403e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.737075685544916
# Old likelihood is : 50.530213434497085
# Data lambda is : 5.199
# Old model lambda is : 5.212485635282977
# New model lambda is : 5.134314029062857
# Data beta is : 0.474
# Old model beta is : 0.33840677849198386
# New model beta is : 0.2561983803407664
# Le delta de likelihood vaut : -0.7931377489521694
# Le a tiré : 0.161782342865
# Le ratio de likelihood : 0.4524229760739163
# True
# Jump accepted.
#
#
# Iteration number 15
# New iteration
# Jump in lamba is 0.010664323500256388
# 0.36955331653198453
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.69553317e-01 5.14497835e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.67367752625546
# Old likelihood is : 49.737075685544916
# Data lambda is : 5.199
# Old model lambda is : 5.134314029062857
# New model lambda is : 5.144978352563113
# Data beta is : 0.474
# Old model beta is : 0.2561983803407664
# New model beta is : 0.36955331653198453
# Le delta de likelihood vaut : 1.9366018407105443
# Le a tiré : 0.232688093642
# Le ratio de likelihood : 6.935144158953209
# True
# Jump accepted.
#
#
# Iteration number 16
# New iteration
# Jump in lamba is -0.05792963521676456
# 0.4559325113074852
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.55932511e-01 5.08704872e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.29486405936761
# Old likelihood is : 51.67367752625546
# Data lambda is : 5.199
# Old model lambda is : 5.144978352563113
# New model lambda is : 5.087048717346349
# Data beta is : 0.474
# Old model beta is : 0.36955331653198453
# New model beta is : 0.4559325113074852
# Le delta de likelihood vaut : -1.3788134668878484
# Le a tiré : 0.297712973448
# Le ratio de likelihood : 0.25187723650712723
# False
# Jump not accepted.
#
#
# Iteration number 17
# New iteration
# Jump in lamba is 0.0240379783633686
# 0.3313860350291317
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.31386035e-01 5.16901633e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.0925915682802
# Old likelihood is : 51.67367752625546
# Data lambda is : 5.199
# Old model lambda is : 5.144978352563113
# New model lambda is : 5.169016330926482
# Data beta is : 0.474
# Old model beta is : 0.36955331653198453
# New model beta is : 0.3313860350291317
# Le delta de likelihood vaut : -0.5810859579752616
# Le a tiré : 0.554000886157
# Le ratio de likelihood : 0.5592906704948132
# True
# Jump accepted.
#
#
# Iteration number 18
# New iteration
# Jump in lamba is -0.021029761993099846
# 0.3842244239902554
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.84224424e-01 5.14798657e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.82509377252983
# Old likelihood is : 51.0925915682802
# Data lambda is : 5.199
# Old model lambda is : 5.169016330926482
# New model lambda is : 5.147986568933382
# Data beta is : 0.474
# Old model beta is : 0.3313860350291317
# New model beta is : 0.3842244239902554
# Le delta de likelihood vaut : 0.7325022042496343
# Le a tiré : 0.379451918254
# Le ratio de likelihood : 2.080279384677461
# True
# Jump accepted.
#
#
# Iteration number 19
# New iteration
# Jump in lamba is -0.04021511731874472
# 0.38099165452675837
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.80991655e-01 5.10777145e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.2699674344727
# Old likelihood is : 51.82509377252983
# Data lambda is : 5.199
# Old model lambda is : 5.147986568933382
# New model lambda is : 5.107771451614637
# Data beta is : 0.474
# Old model beta is : 0.3842244239902554
# New model beta is : 0.38099165452675837
# Le delta de likelihood vaut : -0.5551263380571356
# Le a tiré : 0.432752268571
# Le ratio de likelihood : 0.5739997386035792
# True
# Jump accepted.
#
#
# Iteration number 20
# New iteration
# Jump in lamba is 0.02014703300210688
# 0.29746714785604045
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 2.97467148e-01 5.12791848e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.57841917480485
# Old likelihood is : 51.2699674344727
# Data lambda is : 5.199
# Old model lambda is : 5.107771451614637
# New model lambda is : 5.127918484616743
# Data beta is : 0.474
# Old model beta is : 0.38099165452675837
# New model beta is : 0.29746714785604045
# Le delta de likelihood vaut : -0.6915482596678473
# Le a tiré : 0.273314447589
# Le ratio de likelihood : 0.5008000999238332
# True
# Jump accepted.
#
#
# Iteration number 21
# New iteration
# Jump in lamba is -0.034140879001060394
# 0.28550777148808154
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 2.85507771e-01 5.09377761e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.048826789914095
# Old likelihood is : 50.57841917480485
# Data lambda is : 5.199
# Old model lambda is : 5.127918484616743
# New model lambda is : 5.093777605615683
# Data beta is : 0.474
# Old model beta is : 0.29746714785604045
# New model beta is : 0.28550777148808154
# Le delta de likelihood vaut : -0.5295923848907549
# Le a tiré : 0.795144207584
# Le ratio de likelihood : 0.5888449428623981
# False
# Jump not accepted.
#
#
# Iteration number 22
# New iteration
# Jump in lamba is -0.06735799293042187
# 0.28546020847219095
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 2.85460208e-01 5.06056049e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.33804415698824
# Old likelihood is : 50.57841917480485
# Data lambda is : 5.199
# Old model lambda is : 5.127918484616743
# New model lambda is : 5.060560491686322
# Data beta is : 0.474
# Old model beta is : 0.29746714785604045
# New model beta is : 0.28546020847219095
# Le delta de likelihood vaut : -1.2403750178166106
# Le a tiré : 0.797482618617
# Le ratio de likelihood : 0.28927571404819535
# False
# Jump not accepted.
#
#
# Iteration number 23
# New iteration
# Jump in lamba is 0.10022507618906465
# 0.33690996808726303
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.36909968e-01 5.22814356e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.07262016201293
# Old likelihood is : 50.57841917480485
# Data lambda is : 5.199
# Old model lambda is : 5.127918484616743
# New model lambda is : 5.228143560805808
# Data beta is : 0.474
# Old model beta is : 0.29746714785604045
# New model beta is : 0.33690996808726303
# Le delta de likelihood vaut : -0.5057990127919183
# Le a tiré : 0.210913134869
# Le ratio de likelihood : 0.6030235593464316
# True
# Jump accepted.
#
#
# Iteration number 24
# New iteration
# Jump in lamba is 0.019130715769035026
# 0.39725401794136983
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.97254018e-01 5.24727428e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.81347869432168
# Old likelihood is : 50.07262016201293
# Data lambda is : 5.199
# Old model lambda is : 5.228143560805808
# New model lambda is : 5.247274276574843
# Data beta is : 0.474
# Old model beta is : 0.33690996808726303
# New model beta is : 0.39725401794136983
# Le delta de likelihood vaut : 0.7408585323087493
# Le a tiré : 0.653965671607
# Le ratio de likelihood : 2.0977357155054044
# True
# Jump accepted.
#
#
# Iteration number 25
# New iteration
# Jump in lamba is 0.03858787810518576
# 0.39950073929721863
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.99500739e-01 5.28586215e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.43838127756569
# Old likelihood is : 50.81347869432168
# Data lambda is : 5.199
# Old model lambda is : 5.247274276574843
# New model lambda is : 5.285862154680029
# Data beta is : 0.474
# Old model beta is : 0.39725401794136983
# New model beta is : 0.39950073929721863
# Le delta de likelihood vaut : -1.3750974167559917
# Le a tiré : 0.966074036189
# Le ratio de likelihood : 0.2528149661912249
# False
# Jump not accepted.
#
#
# Iteration number 26
# New iteration
# Jump in lamba is 0.06170645571522707
# 0.4569142410260167
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.56914241e-01 5.30898073e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.73160628229287
# Old likelihood is : 50.81347869432168
# Data lambda is : 5.199
# Old model lambda is : 5.247274276574843
# New model lambda is : 5.30898073229007
# Data beta is : 0.474
# Old model beta is : 0.39725401794136983
# New model beta is : 0.4569142410260167
# Le delta de likelihood vaut : -1.0818724120288081
# Le a tiré : 0.762028092242
# Le ratio de likelihood : 0.33896025782494615
# False
# Jump not accepted.
#
#
# Iteration number 27
# New iteration
# Jump in lamba is 0.03715904935391978
# 0.3947819205121321
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.94781921e-01 5.28443333e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.384650408703415
# Old likelihood is : 50.81347869432168
# Data lambda is : 5.199
# Old model lambda is : 5.247274276574843
# New model lambda is : 5.284433325928763
# Data beta is : 0.474
# Old model beta is : 0.39725401794136983
# New model beta is : 0.3947819205121321
# Le delta de likelihood vaut : -1.4288282856182661
# Le a tiré : 0.548973280797
# Le ratio de likelihood : 0.23958948828916055
# False
# Jump not accepted.
#
#
# Iteration number 28
# New iteration
# Jump in lamba is -0.0923393409286083
# 0.4438386272340715
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.43838627e-01 5.15493494e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.103776770668205
# Old likelihood is : 50.81347869432168
# Data lambda is : 5.199
# Old model lambda is : 5.247274276574843
# New model lambda is : 5.154934935646235
# Data beta is : 0.474
# Old model beta is : 0.39725401794136983
# New model beta is : 0.4438386272340715
# Le delta de likelihood vaut : 1.2902980763465237
# Le a tiré : 0.22717944736
# Le ratio de likelihood : 3.6338695648987343
# True
# Jump accepted.
#
#
# Iteration number 29
# New iteration
# Jump in lamba is 0.01078831629435558
# 0.344835195308263
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.44835195e-01 5.16572325e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.34501033075203
# Old likelihood is : 52.103776770668205
# Data lambda is : 5.199
# Old model lambda is : 5.154934935646235
# New model lambda is : 5.165723251940591
# Data beta is : 0.474
# Old model beta is : 0.4438386272340715
# New model beta is : 0.344835195308263
# Le delta de likelihood vaut : -0.7587664399161724
# Le a tiré : 0.641074497303
# Le ratio de likelihood : 0.46824367761026564
# False
# Jump not accepted.
#
#
# Iteration number 30
# New iteration
# Jump in lamba is -0.035182237618779554
# 0.4389457666156584
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.38945767e-01 5.11975270e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.486869966086886
# Old likelihood is : 52.103776770668205
# Data lambda is : 5.199
# Old model lambda is : 5.154934935646235
# New model lambda is : 5.1197526980274555
# Data beta is : 0.474
# Old model beta is : 0.4438386272340715
# New model beta is : 0.4389457666156584
# Le delta de likelihood vaut : -0.6169068045813191
# Le a tiré : 0.584134878582
# Le ratio de likelihood : 0.5396109810080021
# False
# Jump not accepted.
#
#
# Iteration number 31
# New iteration
# Jump in lamba is 0.018675372215863243
# 0.5592780733974927
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.59278073e-01 5.17361031e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.06115799776552
# Old likelihood is : 52.103776770668205
# Data lambda is : 5.199
# Old model lambda is : 5.154934935646235
# New model lambda is : 5.1736103078620985
# Data beta is : 0.474
# Old model beta is : 0.4438386272340715
# New model beta is : 0.5592780733974927
# Le delta de likelihood vaut : -1.042618772902685
# Le a tiré : 0.424965364636
# Le ratio de likelihood : 0.3525302753491257
# False
# Jump not accepted.
#
#
# Iteration number 32
# New iteration
# Jump in lamba is 0.05865957022793187
# 0.4572291728276946
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.57229173e-01 5.21359451e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.23556718364111
# Old likelihood is : 52.103776770668205
# Data lambda is : 5.199
# Old model lambda is : 5.154934935646235
# New model lambda is : 5.213594505874167
# Data beta is : 0.474
# Old model beta is : 0.4438386272340715
# New model beta is : 0.4572291728276946
# Le delta de likelihood vaut : 0.1317904129729044
# Le a tiré : 0.293271859198
# Le ratio de likelihood : 1.1408691828278288
# True
# Jump accepted.
#
#
# Iteration number 33
# New iteration
# Jump in lamba is 0.04529921517906474
# 0.5438756147066801
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.43875615e-01 5.25889372e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.907516923165595
# Old likelihood is : 52.23556718364111
# Data lambda is : 5.199
# Old model lambda is : 5.213594505874167
# New model lambda is : 5.258893721053232
# Data beta is : 0.474
# Old model beta is : 0.4572291728276946
# New model beta is : 0.5438756147066801
# Le delta de likelihood vaut : -0.3280502604755142
# Le a tiré : 0.193023309588
# Le ratio de likelihood : 0.7203268148272329
# True
# Jump accepted.
#
#
# Iteration number 34
# New iteration
# Jump in lamba is -0.02443849874760458
# 0.6345234326570267
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 6.34523433e-01 5.23445522e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.259041868300024
# Old likelihood is : 51.907516923165595
# Data lambda is : 5.199
# Old model lambda is : 5.258893721053232
# New model lambda is : 5.234455222305627
# Data beta is : 0.474
# Old model beta is : 0.5438756147066801
# New model beta is : 0.6345234326570267
# Le delta de likelihood vaut : -1.648475054865571
# Le a tiré : 0.160945046529
# Le ratio de likelihood : 0.1923429976099897
# True
# Jump accepted.
#
#
# Iteration number 35
# New iteration
# Jump in lamba is -0.002411878358638337
# 0.6178322397033946
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 6.17832240e-01 5.23204334e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.71348799277877
# Old likelihood is : 50.259041868300024
# Data lambda is : 5.199
# Old model lambda is : 5.234455222305627
# New model lambda is : 5.232043343946988
# Data beta is : 0.474
# Old model beta is : 0.6345234326570267
# New model beta is : 0.6178322397033946
# Le delta de likelihood vaut : 0.4544461244787428
# Le a tiré : 0.502402304102
# Le ratio de likelihood : 1.5753006209029736
# True
# Jump accepted.
#
#
# Iteration number 36
# New iteration
# Jump in lamba is -0.012993076786374859
# 0.5733113986000649
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.73311399e-01 5.21905027e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.568166006167566
# Old likelihood is : 50.71348799277877
# Data lambda is : 5.199
# Old model lambda is : 5.232043343946988
# New model lambda is : 5.219050267160613
# Data beta is : 0.474
# Old model beta is : 0.6178322397033946
# New model beta is : 0.5733113986000649
# Le delta de likelihood vaut : 0.8546780133887992
# Le a tiré : 0.201572127077
# Le ratio de likelihood : 2.3506173913831687
# True
# Jump accepted.
#
#
# Iteration number 37
# New iteration
# Jump in lamba is -0.042087252468302805
# 0.6147444348300666
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 6.14744435e-01 5.17696301e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.460440485362895
# Old likelihood is : 51.568166006167566
# Data lambda is : 5.199
# Old model lambda is : 5.219050267160613
# New model lambda is : 5.17696301469231
# Data beta is : 0.474
# Old model beta is : 0.5733113986000649
# New model beta is : 0.6147444348300666
# Le delta de likelihood vaut : -2.107725520804671
# Le a tiré : 0.587365822761
# Le ratio de likelihood : 0.12151403350110566
# False
# Jump not accepted.
#
#
# Iteration number 38
# New iteration
# Jump in lamba is 0.02108487341265789
# 0.5003990611914756
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.00399061e-01 5.24013514e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.1405592296629
# Old likelihood is : 51.568166006167566
# Data lambda is : 5.199
# Old model lambda is : 5.219050267160613
# New model lambda is : 5.240135140573271
# Data beta is : 0.474
# Old model beta is : 0.5733113986000649
# New model beta is : 0.5003990611914756
# Le delta de likelihood vaut : 0.5723932234953324
# Le a tiré : 0.338273671046
# Le ratio de likelihood : 1.7725039776206417
# True
# Jump accepted.
#
#
# Iteration number 39
# New iteration
# Jump in lamba is -0.06667444534471872
# 0.5660537122781253
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.66053712e-01 5.17346070e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.89087591460793
# Old likelihood is : 52.1405592296629
# Data lambda is : 5.199
# Old model lambda is : 5.240135140573271
# New model lambda is : 5.1734606952285525
# Data beta is : 0.474
# Old model beta is : 0.5003990611914756
# New model beta is : 0.5660537122781253
# Le delta de likelihood vaut : -1.2496833150549662
# Le a tiré : 0.452922096138
# Le ratio de likelihood : 0.28659554298424295
# False
# Jump not accepted.
#
#
# Iteration number 40
# New iteration
# Jump in lamba is -0.08199486680215655
# 0.6013882176501254
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 6.01388218e-01 5.15814027e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.285026109699416
# Old likelihood is : 52.1405592296629
# Data lambda is : 5.199
# Old model lambda is : 5.240135140573271
# New model lambda is : 5.158140273771115
# Data beta is : 0.474
# Old model beta is : 0.5003990611914756
# New model beta is : 0.6013882176501254
# Le delta de likelihood vaut : -2.855533119963482
# Le a tiré : 0.521667822511
# Le ratio de likelihood : 0.05752514514135099
# False
# Jump not accepted.
#
#
# Iteration number 41
# New iteration
# Jump in lamba is 0.029559966463523924
# 0.41435478302062656
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.14354783e-01 5.26969511e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.41900815438347
# Old likelihood is : 52.1405592296629
# Data lambda is : 5.199
# Old model lambda is : 5.240135140573271
# New model lambda is : 5.269695107036795
# Data beta is : 0.474
# Old model beta is : 0.5003990611914756
# New model beta is : 0.41435478302062656
# Le delta de likelihood vaut : -1.7215510752794287
# Le a tiré : 0.511358456989
# Le ratio de likelihood : 0.17878861812652047
# False
# Jump not accepted.
#
#
# Iteration number 42
# New iteration
# Jump in lamba is 0.04625896352160516
# 0.397682442589254
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.97682443e-01 5.28639410e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.37007705753565
# Old likelihood is : 52.1405592296629
# Data lambda is : 5.199
# Old model lambda is : 5.240135140573271
# New model lambda is : 5.286394104094876
# Data beta is : 0.474
# Old model beta is : 0.5003990611914756
# New model beta is : 0.397682442589254
# Le delta de likelihood vaut : -2.7704821721272452
# Le a tiré : 0.710030256052
# Le ratio de likelihood : 0.06263179815300207
# False
# Jump not accepted.
#
#
# Iteration number 43
# New iteration
# Jump in lamba is -0.02232232416258907
# 0.5127409651264737
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.12740965e-01 5.21781282e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.2503936092497
# Old likelihood is : 52.1405592296629
# Data lambda is : 5.199
# Old model lambda is : 5.240135140573271
# New model lambda is : 5.217812816410682
# Data beta is : 0.474
# Old model beta is : 0.5003990611914756
# New model beta is : 0.5127409651264737
# Le delta de likelihood vaut : 0.10983437958680042
# Le a tiré : 0.0257793103801
# Le ratio de likelihood : 1.1160932073325724
# True
# Jump accepted.
#
#
# Iteration number 44
# New iteration
# Jump in lamba is -0.08078214272100212
# 0.5807037502346616
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.80703750e-01 5.13703067e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.20662364393117
# Old likelihood is : 52.2503936092497
# Data lambda is : 5.199
# Old model lambda is : 5.217812816410682
# New model lambda is : 5.137030673689679
# Data beta is : 0.474
# Old model beta is : 0.5127409651264737
# New model beta is : 0.5807037502346616
# Le delta de likelihood vaut : -3.043769965318532
# Le a tiré : 0.921192611421
# Le ratio de likelihood : 0.047654893123013076
# False
# Jump not accepted.
#
#
# Iteration number 45
# New iteration
# Jump in lamba is 0.006965589658392089
# 0.4382285219476648
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.38228522e-01 5.22477841e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.94949408481999
# Old likelihood is : 52.2503936092497
# Data lambda is : 5.199
# Old model lambda is : 5.217812816410682
# New model lambda is : 5.224778406069074
# Data beta is : 0.474
# Old model beta is : 0.5127409651264737
# New model beta is : 0.4382285219476648
# Le delta de likelihood vaut : -0.3008995244297097
# Le a tiré : 0.606277389497
# Le ratio de likelihood : 0.7401521362187772
# True
# Jump accepted.
#
#
# Iteration number 46
# New iteration
# Jump in lamba is 0.10026809469529258
# 0.4306985760867663
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.30698576e-01 5.32504650e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 48.322834970939745
# Old likelihood is : 51.94949408481999
# Data lambda is : 5.199
# Old model lambda is : 5.224778406069074
# New model lambda is : 5.325046500764366
# Data beta is : 0.474
# Old model beta is : 0.4382285219476648
# New model beta is : 0.4306985760867663
# Le delta de likelihood vaut : -3.626659113880244
# Le a tiré : 0.945303915264
# Le ratio de likelihood : 0.026604920106729935
# False
# Jump not accepted.
#
#
# Iteration number 47
# New iteration
# Jump in lamba is -0.008348909971533296
# 0.43832030555191015
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.38320306e-01 5.21642950e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.06656093603591
# Old likelihood is : 51.94949408481999
# Data lambda is : 5.199
# Old model lambda is : 5.224778406069074
# New model lambda is : 5.216429496097541
# Data beta is : 0.474
# Old model beta is : 0.4382285219476648
# New model beta is : 0.43832030555191015
# Le delta de likelihood vaut : 0.11706685121592386
# Le a tiré : 0.612545828945
# Le ratio de likelihood : 1.124194580953204
# True
# Jump accepted.
#
#
# Iteration number 48
# New iteration
# Jump in lamba is -0.000967880936851538
# 0.4214636127218805
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.21463613e-01 5.21546162e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.90258217466634
# Old likelihood is : 52.06656093603591
# Data lambda is : 5.199
# Old model lambda is : 5.216429496097541
# New model lambda is : 5.215461615160689
# Data beta is : 0.474
# Old model beta is : 0.43832030555191015
# New model beta is : 0.4214636127218805
# Le delta de likelihood vaut : -0.16397876136957024
# Le a tiré : 0.804151029784
# Le ratio de likelihood : 0.848760048189766
# True
# Jump accepted.
#
#
# Iteration number 49
# New iteration
# Jump in lamba is -0.003657066107385472
# 0.44132292200777273
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.41322922e-01 5.21180455e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.14428593673281
# Old likelihood is : 51.90258217466634
# Data lambda is : 5.199
# Old model lambda is : 5.215461615160689
# New model lambda is : 5.211804549053303
# Data beta is : 0.474
# Old model beta is : 0.4214636127218805
# New model beta is : 0.44132292200777273
# Le delta de likelihood vaut : 0.24170376206646438
# Le a tiré : 0.207501210625
# Le ratio de likelihood : 1.27341690254337
# True
# Jump accepted.
#
#
# Iteration number 50
# New iteration
# Jump in lamba is -0.026259272029984206
# 0.5420461629603239
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.42046163e-01 5.18554528e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.66244526647801
# Old likelihood is : 52.14428593673281
# Data lambda is : 5.199
# Old model lambda is : 5.211804549053303
# New model lambda is : 5.185545277023319
# Data beta is : 0.474
# Old model beta is : 0.44132292200777273
# New model beta is : 0.5420461629603239
# Le delta de likelihood vaut : -0.4818406702547975
# Le a tiré : 0.198223778411
# Le ratio de likelihood : 0.6176454632196128
# True
# Jump accepted.
#
#
# Iteration number 51
# New iteration
# Jump in lamba is 0.014733219295154627
# 0.43594591549274386
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.35945915e-01 5.20027850e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.19968730044822
# Old likelihood is : 51.66244526647801
# Data lambda is : 5.199
# Old model lambda is : 5.185545277023319
# New model lambda is : 5.200278496318474
# Data beta is : 0.474
# Old model beta is : 0.5420461629603239
# New model beta is : 0.43594591549274386
# Le delta de likelihood vaut : 0.5372420339702089
# Le a tiré : 0.85314444301
# Le ratio de likelihood : 1.7112806938536693
# True
# Jump accepted.
#
#
# Iteration number 52
# New iteration
# Jump in lamba is 0.08196807750719677
# 0.4311624044594355
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.31162404e-01 5.28224657e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.29797988734006
# Old likelihood is : 52.19968730044822
# Data lambda is : 5.199
# Old model lambda is : 5.200278496318474
# New model lambda is : 5.282246573825671
# Data beta is : 0.474
# Old model beta is : 0.43594591549274386
# New model beta is : 0.4311624044594355
# Le delta de likelihood vaut : -1.9017074131081557
# Le a tiré : 0.698077771784
# Le ratio de likelihood : 0.14931346169324827
# False
# Jump not accepted.
#
#
# Iteration number 53
# New iteration
# Jump in lamba is -0.0016915757933193482
# 0.40938841076129107
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.09388411e-01 5.19858692e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.96945914128578
# Old likelihood is : 52.19968730044822
# Data lambda is : 5.199
# Old model lambda is : 5.200278496318474
# New model lambda is : 5.198586920525155
# Data beta is : 0.474
# Old model beta is : 0.43594591549274386
# New model beta is : 0.40938841076129107
# Le delta de likelihood vaut : -0.23022815916243644
# Le a tiré : 0.894516752166
# Le ratio de likelihood : 0.7943523430608468
# False
# Jump not accepted.
#
#
# Iteration number 54
# New iteration
# Jump in lamba is 0.06321382193450951
# 0.34321501632494844
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.43215016e-01 5.26349232e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 48.95031158803092
# Old likelihood is : 52.19968730044822
# Data lambda is : 5.199
# Old model lambda is : 5.200278496318474
# New model lambda is : 5.263492318252983
# Data beta is : 0.474
# Old model beta is : 0.43594591549274386
# New model beta is : 0.34321501632494844
# Le delta de likelihood vaut : -3.2493757124172973
# Le a tiré : 0.374481233299
# Le ratio de likelihood : 0.03879842164560574
# False
# Jump not accepted.
#
#
# Iteration number 55
# New iteration
# Jump in lamba is 0.021585035503396518
# 0.4659796044415679
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.65979604e-01 5.22186353e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.20744023536255
# Old likelihood is : 52.19968730044822
# Data lambda is : 5.199
# Old model lambda is : 5.200278496318474
# New model lambda is : 5.221863531821871
# Data beta is : 0.474
# Old model beta is : 0.43594591549274386
# New model beta is : 0.4659796044415679
# Le delta de likelihood vaut : 0.007752934914329046
# Le a tiré : 0.277541657852
# Le ratio de likelihood : 1.0077830667338978
# True
# Jump accepted.
#
#
# Iteration number 56
# New iteration
# Jump in lamba is 0.11835913749242317
# 0.3779894134950193
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.77989413e-01 5.34022267e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 45.825408862415614
# Old likelihood is : 52.20744023536255
# Data lambda is : 5.199
# Old model lambda is : 5.221863531821871
# New model lambda is : 5.3402226693142945
# Data beta is : 0.474
# Old model beta is : 0.4659796044415679
# New model beta is : 0.3779894134950193
# Le delta de likelihood vaut : -6.382031372946933
# Le a tiré : 0.344058635779
# Le ratio de likelihood : 0.00169168302478258
# False
# Jump not accepted.
#
#
# Iteration number 57
# New iteration
# Jump in lamba is 0.047062698270325526
# 0.41401059357590153
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.14010594e-01 5.26892623e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.43943511810897
# Old likelihood is : 52.20744023536255
# Data lambda is : 5.199
# Old model lambda is : 5.221863531821871
# New model lambda is : 5.268926230092196
# Data beta is : 0.474
# Old model beta is : 0.4659796044415679
# New model beta is : 0.41401059357590153
# Le delta de likelihood vaut : -1.7680051172535798
# Le a tiré : 0.306944682509
# Le ratio de likelihood : 0.17067312231638135
# False
# Jump not accepted.
#
#
# Iteration number 58
# New iteration
# Jump in lamba is -0.10998816965497388
# 0.5105190589451876
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.10519059e-01 5.11187536e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.253528798661605
# Old likelihood is : 52.20744023536255
# Data lambda is : 5.199
# Old model lambda is : 5.221863531821871
# New model lambda is : 5.111875362166897
# Data beta is : 0.474
# Old model beta is : 0.4659796044415679
# New model beta is : 0.5105190589451876
# Le delta de likelihood vaut : -1.9539114367009418
# Le a tiré : 0.99639792481
# Le ratio de likelihood : 0.14171866249318923
# False
# Jump not accepted.
#
#
# Iteration number 59
# New iteration
# Jump in lamba is 0.042436636861231974
# 0.5196931479943392
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.19693148e-01 5.26430017e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.850122487302464
# Old likelihood is : 52.20744023536255
# Data lambda is : 5.199
# Old model lambda is : 5.221863531821871
# New model lambda is : 5.264300168683103
# Data beta is : 0.474
# Old model beta is : 0.4659796044415679
# New model beta is : 0.5196931479943392
# Le delta de likelihood vaut : -0.3573177480600833
# Le a tiré : 0.975375214442
# Le ratio de likelihood : 0.6995501817030706
# False
# Jump not accepted.
#
#
# Iteration number 60
# New iteration
# Jump in lamba is 0.05919218106635565
# 0.3670542119975902
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.67054212e-01 5.28105571e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 48.816413175619125
# Old likelihood is : 52.20744023536255
# Data lambda is : 5.199
# Old model lambda is : 5.221863531821871
# New model lambda is : 5.281055712888227
# Data beta is : 0.474
# Old model beta is : 0.4659796044415679
# New model beta is : 0.3670542119975902
# Le delta de likelihood vaut : -3.391027059743422
# Le a tiré : 0.858006281631
# Le ratio de likelihood : 0.0336740738472676
# False
# Jump not accepted.
#
#
# Iteration number 61
# New iteration
# Jump in lamba is -0.09150845363156443
# 0.44421542427971744
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.44215424e-01 5.13035508e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.69874885796008
# Old likelihood is : 52.20744023536255
# Data lambda is : 5.199
# Old model lambda is : 5.221863531821871
# New model lambda is : 5.1303550781903065
# Data beta is : 0.474
# Old model beta is : 0.4659796044415679
# New model beta is : 0.44421542427971744
# Le delta de likelihood vaut : -0.5086913774024708
# Le a tiré : 0.69538325374
# Le ratio de likelihood : 0.6012819152930438
# False
# Jump not accepted.
#
#
# Iteration number 62
# New iteration
# Jump in lamba is 0.0445598604997602
# 0.4398507437634087
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.39850744e-01 5.26642339e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.00442380796095
# Old likelihood is : 52.20744023536255
# Data lambda is : 5.199
# Old model lambda is : 5.221863531821871
# New model lambda is : 5.266423392321631
# Data beta is : 0.474
# Old model beta is : 0.4659796044415679
# New model beta is : 0.4398507437634087
# Le delta de likelihood vaut : -1.2030164274016002
# Le a tiré : 0.290429046459
# Le ratio de likelihood : 0.30028705031957226
# True
# Jump accepted.
#
#
# Iteration number 63
# New iteration
# Jump in lamba is 0.020037234661810472
# 0.434207838547188
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.34207839e-01 5.28646063e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.197273433191626
# Old likelihood is : 51.00442380796095
# Data lambda is : 5.199
# Old model lambda is : 5.266423392321631
# New model lambda is : 5.286460626983441
# Data beta is : 0.474
# Old model beta is : 0.4398507437634087
# New model beta is : 0.434207838547188
# Le delta de likelihood vaut : -0.8071503747693214
# Le a tiré : 0.94091468529
# Le ratio de likelihood : 0.4461275529141158
# False
# Jump not accepted.
#
#
# Iteration number 64
# New iteration
# Jump in lamba is 0.0804356687100544
# 0.42892471188551184
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.28924712e-01 5.34685906e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 47.017062717536746
# Old likelihood is : 51.00442380796095
# Data lambda is : 5.199
# Old model lambda is : 5.266423392321631
# New model lambda is : 5.346859061031685
# Data beta is : 0.474
# Old model beta is : 0.4398507437634087
# New model beta is : 0.42892471188551184
# Le delta de likelihood vaut : -3.9873610904242014
# Le a tiré : 0.904264102767
# Le ratio de likelihood : 0.01854859766381764
# False
# Jump not accepted.
#
#
# Iteration number 65
# New iteration
# Jump in lamba is -0.023948132486338203
# 0.453077033384326
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.53077033e-01 5.24247526e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.7951656828886
# Old likelihood is : 51.00442380796095
# Data lambda is : 5.199
# Old model lambda is : 5.266423392321631
# New model lambda is : 5.242475259835293
# Data beta is : 0.474
# Old model beta is : 0.4398507437634087
# New model beta is : 0.453077033384326
# Le delta de likelihood vaut : 0.7907418749276545
# Le a tiré : 0.936392888984
# Le ratio de likelihood : 2.205031677321142
# True
# Jump accepted.
#
#
# Iteration number 66
# New iteration
# Jump in lamba is -0.0027183079268013103
# 0.4813287720101169
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.81328772e-01 5.23975695e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 52.07419030775909
# Old likelihood is : 51.7951656828886
# Data lambda is : 5.199
# Old model lambda is : 5.242475259835293
# New model lambda is : 5.2397569519084914
# Data beta is : 0.474
# Old model beta is : 0.453077033384326
# New model beta is : 0.4813287720101169
# Le delta de likelihood vaut : 0.2790246248704875
# Le a tiré : 0.112573064656
# Le ratio de likelihood : 1.3218398936049562
# True
# Jump accepted.
#
#
# Iteration number 67
# New iteration
# ...
#
#
# Iteration number 178
# New iteration
# Jump in lamba is 0.05392278061877033
# 0.4523162326142935
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.52316233e-01 5.26208786e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.32280590016228
# Old likelihood is : 52.28812140224494
# Data lambda is : 5.199
# Old model lambda is : 5.2081650774561705
# New model lambda is : 5.262087858074941
# Data beta is : 0.474
# Old model beta is : 0.4602504348752153
# New model beta is : 0.4523162326142935
# Le delta de likelihood vaut : -0.9653155020826603
# Le a tiré : 0.0549299983137
# Le ratio de likelihood : 0.3808630177061987
# True
# Jump accepted.
#
#
# Iteration number 179
# New iteration
# Jump in lamba is 0.03936628567384878
# 0.40370251204269814
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.03702512e-01 5.30145414e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 48.8210500873224
# Old likelihood is : 51.32280590016228
# Data lambda is : 5.199
# Old model lambda is : 5.262087858074941
# New model lambda is : 5.301454143748789
# Data beta is : 0.474
# Old model beta is : 0.4523162326142935
# New model beta is : 0.40370251204269814
# Le delta de likelihood vaut : -2.501755812839882
# Le a tiré : 0.192791409184
# Le ratio de likelihood : 0.0819409991843801
# False
# Jump not accepted.
#
#
# Iteration number 180
# New iteration
# Jump in lamba is 0.011010287701754407
# 0.31647639410799294
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.16476394e-01 5.27309815e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 47.748437884135726
# Old likelihood is : 51.32280590016228
# Data lambda is : 5.199
# Old model lambda is : 5.262087858074941
# New model lambda is : 5.273098145776696
# Data beta is : 0.474
# Old model beta is : 0.4523162326142935
# New model beta is : 0.31647639410799294
# Le delta de likelihood vaut : -3.574368016026554
# Le a tiré : 0.369455145002
# Le ratio de likelihood : 0.02803313667023212
# False
# Jump not accepted.
#
#
# Iteration number 181
# New iteration
# Jump in lamba is -0.012928667009200473
# 0.5680285522194772
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.68028552e-01 5.24915919e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.78446863311358
# Old likelihood is : 51.32280590016228
# Data lambda is : 5.199
# Old model lambda is : 5.262087858074941
# New model lambda is : 5.249159191065741
# Data beta is : 0.474
# Old model beta is : 0.4523162326142935
# New model beta is : 0.5680285522194772
# Le delta de likelihood vaut : 0.46166273295130367
# Le a tiré : 0.0551664827024
# Le ratio de likelihood : 1.5867100679503041
# True
# Jump accepted.
#
#
# Iteration number 182
# New iteration
# Jump in lamba is -0.03208541342534567
# 0.6719131543842508
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 6.71913154e-01 5.21707378e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 48.37873272528341
# Old likelihood is : 51.78446863311358
# Data lambda is : 5.199
# Old model lambda is : 5.249159191065741
# New model lambda is : 5.217073777640395
# Data beta is : 0.474
# Old model beta is : 0.5680285522194772
# New model beta is : 0.6719131543842508
# Le delta de likelihood vaut : -3.40573590783017
# Le a tiré : 0.796402027738
# Le ratio de likelihood : 0.03318239191262034
# False
# Jump not accepted.
#
#
# Iteration number 183
# New iteration
# Jump in lamba is -0.05548648299333495
# 0.590954280506084
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.90954281e-01 5.19367271e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.72438467727162
# Old likelihood is : 51.78446863311358
# Data lambda is : 5.199
# Old model lambda is : 5.249159191065741
# New model lambda is : 5.193672708072405
# Data beta is : 0.474
# Old model beta is : 0.5680285522194772
# New model beta is : 0.590954280506084
# Le delta de likelihood vaut : -1.0600839558419608
# Le a tiré : 0.758766945388
# Le ratio de likelihood : 0.34642672456177614
# False
# Jump not accepted.
#
#
# Iteration number 184
# New iteration
# Jump in lamba is -0.02446591889220543
# 0.6659637165527803
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 6.65963717e-01 5.22469327e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 48.869166316590004
# Old likelihood is : 51.78446863311358
# Data lambda is : 5.199
# Old model lambda is : 5.249159191065741
# New model lambda is : 5.2246932721735355
# Data beta is : 0.474
# Old model beta is : 0.5680285522194772
# New model beta is : 0.6659637165527803
# Le delta de likelihood vaut : -2.9153023165235794
# Le a tiré : 0.741144119791
# Le ratio de likelihood : 0.0541876467354943
# False
# Jump not accepted.
#
#
# Iteration number 185
# New iteration
# Jump in lamba is 0.013089529215405056
# 0.5268121803133704
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.26812180e-01 5.26224872e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.89276835801733
# Old likelihood is : 51.78446863311358
# Data lambda is : 5.199
# Old model lambda is : 5.249159191065741
# New model lambda is : 5.262248720281145
# Data beta is : 0.474
# Old model beta is : 0.5680285522194772
# New model beta is : 0.5268121803133704
# Le delta de likelihood vaut : 0.10829972490374473
# Le a tiré : 0.757466688085
# Le ratio de likelihood : 1.1143817032849699
# True
# Jump accepted.
#
#
# Iteration number 186
# New iteration
# Jump in lamba is -0.003255278967114833
# 0.5165077647990001
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.16507765e-01 5.25899344e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.92681379625734
# Old likelihood is : 51.89276835801733
# Data lambda is : 5.199
# Old model lambda is : 5.262248720281145
# New model lambda is : 5.258993441314031
# Data beta is : 0.474
# Old model beta is : 0.5268121803133704
# New model beta is : 0.5165077647990001
# Le delta de likelihood vaut : 0.03404543824001394
# Le a tiré : 0.95258349362
# Le ratio de likelihood : 1.0346316174998285
# True
# Jump accepted.
#
#
# Iteration number 187
# New iteration
# Jump in lamba is 0.07226178797773498
# 0.5441582083968609
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.44158208e-01 5.33125523e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.2208864781763
# Old likelihood is : 51.92681379625734
# Data lambda is : 5.199
# Old model lambda is : 5.258993441314031
# New model lambda is : 5.331255229291766
# Data beta is : 0.474
# Old model beta is : 0.5165077647990001
# New model beta is : 0.5441582083968609
# Le delta de likelihood vaut : -1.705927318081045
# Le a tiré : 0.36926527626
# Le ratio de likelihood : 0.18160390348562813
# False
# Jump not accepted.
#
#
# Iteration number 188
# New iteration
# Jump in lamba is -0.03766363216189679
# 0.6220226977082471
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 6.22022698e-01 5.22132981e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.40551463191792
# Old likelihood is : 51.92681379625734
# Data lambda is : 5.199
# Old model lambda is : 5.258993441314031
# New model lambda is : 5.2213298091521345
# Data beta is : 0.474
# Old model beta is : 0.5165077647990001
# New model beta is : 0.6220226977082471
# Le delta de likelihood vaut : -1.5212991643394247
# Le a tiré : 0.182818588716
# Le ratio de likelihood : 0.21842792876219472
# True
# Jump accepted.
#
#
# Iteration number 189
# New iteration
# Jump in lamba is 0.07135314809703293
# 0.6945749433837914
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 6.94574943e-01 5.29268296e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 48.99122802951586
# Old likelihood is : 50.40551463191792
# Data lambda is : 5.199
# Old model lambda is : 5.2213298091521345
# New model lambda is : 5.292682957249167
# Data beta is : 0.474
# Old model beta is : 0.6220226977082471
# New model beta is : 0.6945749433837914
# Le delta de likelihood vaut : -1.4142866024020577
# Le a tiré : 0.582310013084
# Le ratio de likelihood : 0.24309897782936918
# False
# Jump not accepted.
#
#
# Iteration number 190
# New iteration
# Jump in lamba is -0.027330070082664262
# 0.6295123146003248
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 6.29512315e-01 5.19399974e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.45146139732367
# Old likelihood is : 50.40551463191792
# Data lambda is : 5.199
# Old model lambda is : 5.2213298091521345
# New model lambda is : 5.19399973906947
# Data beta is : 0.474
# Old model beta is : 0.6220226977082471
# New model beta is : 0.6295123146003248
# Le delta de likelihood vaut : -0.9540532345942481
# Le a tiré : 0.827316274305
# Le ratio de likelihood : 0.38517664389961337
# False
# Jump not accepted.
#
#
# Iteration number 191
# New iteration
# Jump in lamba is 0.05162077248866495
# 0.5670728103605
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.67072810e-01 5.27295058e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.64843222041971
# Old likelihood is : 50.40551463191792
# Data lambda is : 5.199
# Old model lambda is : 5.2213298091521345
# New model lambda is : 5.272950581640799
# Data beta is : 0.474
# Old model beta is : 0.6220226977082471
# New model beta is : 0.5670728103605
# Le delta de likelihood vaut : 1.2429175885017898
# Le a tiré : 0.369414688745
# Le ratio de likelihood : 3.4657102448365684
# True
# Jump accepted.
#
#
# Iteration number 192
# New iteration
# Jump in lamba is -0.056907116749439636
# 0.5700019473385974
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.70001947e-01 5.21604346e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.59610087771383
# Old likelihood is : 51.64843222041971
# Data lambda is : 5.199
# Old model lambda is : 5.272950581640799
# New model lambda is : 5.21604346489136
# Data beta is : 0.474
# Old model beta is : 0.5670728103605
# New model beta is : 0.5700019473385974
# Le delta de likelihood vaut : -0.05233134270587669
# Le a tiré : 0.764342551022
# Le ratio de likelihood : 0.9490143657540813
# True
# Jump accepted.
#
#
# Iteration number 193
# New iteration
# Jump in lamba is 0.040289789574688886
# 0.5216774317660028
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 5.21677432e-01 5.25633325e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.97138852199806
# Old likelihood is : 51.59610087771383
# Data lambda is : 5.199
# Old model lambda is : 5.21604346489136
# New model lambda is : 5.256333254466049
# Data beta is : 0.474
# Old model beta is : 0.5700019473385974
# New model beta is : 0.5216774317660028
# Le delta de likelihood vaut : 0.3752876442842279
# Le a tiré : 0.182424301801
# Le ratio de likelihood : 1.4554099947804264
# True
# Jump accepted.
#
#
# Iteration number 194
# New iteration
# Jump in lamba is 0.0669177301716561
# 0.42580247717278863
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.25802477e-01 5.32325098e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 48.28817537281893
# Old likelihood is : 51.97138852199806
# Data lambda is : 5.199
# Old model lambda is : 5.256333254466049
# New model lambda is : 5.3232509846377045
# Data beta is : 0.474
# Old model beta is : 0.5216774317660028
# New model beta is : 0.42580247717278863
# Le delta de likelihood vaut : -3.6832131491791316
# Le a tiré : 0.552168136474
# Le ratio de likelihood : 0.025142059720124153
# False
# Jump not accepted.
#
#
# Iteration number 195
# New iteration
# Jump in lamba is -0.009780206931291228
# 0.3600247349001381
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.60024735e-01 5.24655305e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.02851899034241
# Old likelihood is : 51.97138852199806
# Data lambda is : 5.199
# Old model lambda is : 5.256333254466049
# New model lambda is : 5.246553047534758
# Data beta is : 0.474
# Old model beta is : 0.5216774317660028
# New model beta is : 0.3600247349001381
# Le delta de likelihood vaut : -1.9428695316556457
# Le a tiré : 0.000526077455322
# Le ratio de likelihood : 0.14329217782365444
# True
# Jump accepted.
#
#
# Iteration number 196
# New iteration
# Jump in lamba is 0.016953396660995834
# 0.3953690637700422
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.95369064e-01 5.26350644e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 50.2376278166744
# Old likelihood is : 50.02851899034241
# Data lambda is : 5.199
# Old model lambda is : 5.246553047534758
# New model lambda is : 5.2635064441957535
# Data beta is : 0.474
# Old model beta is : 0.3600247349001381
# New model beta is : 0.3953690637700422
# Le delta de likelihood vaut : 0.2091088263319847
# Le a tiré : 0.740933272121
# Le ratio de likelihood : 1.2325791282971106
# True
# Jump accepted.
#
#
# Iteration number 197
# New iteration
# Jump in lamba is -0.018940974172397002
# 0.42113309853863384
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.21133099e-01 5.24456547e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 51.315368806171826
# Old likelihood is : 50.2376278166744
# Data lambda is : 5.199
# Old model lambda is : 5.2635064441957535
# New model lambda is : 5.244565470023357
# Data beta is : 0.474
# Old model beta is : 0.3953690637700422
# New model beta is : 0.42113309853863384
# Le delta de likelihood vaut : 1.0777409894974284
# Le a tiré : 0.643484981203
# Le ratio de likelihood : 2.938034996917429
# True
# Jump accepted.
#
#
# Iteration number 198
# New iteration
# Jump in lamba is 0.0017765238509355715
# 0.345773277157901
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 3.45773277e-01 5.24634199e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.68901123836792
# Old likelihood is : 51.315368806171826
# Data lambda is : 5.199
# Old model lambda is : 5.244565470023357
# New model lambda is : 5.246341993874292
# Data beta is : 0.474
# Old model beta is : 0.42113309853863384
# New model beta is : 0.345773277157901
# Le delta de likelihood vaut : -1.6263575678039075
# Le a tiré : 0.936464946488
# Le ratio de likelihood : 0.1966445356247974
# False
# Jump not accepted.
#
#
# Iteration number 199
# New iteration
# Jump in lamba is 0.03729996325104253
# 0.4049204196317388
# Rebuilt parameters are : [6.28318531e-03 0.00000000e+00 4.04920420e-01 5.28186543e+00
#  7.00000000e-22 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Begin calculating likelihood for MH criterion.
# Calculated ok.
# New likelihood is : 49.73927251833938
# Old likelihood is : 51.315368806171826
# Data lambda is : 5.199
# Old model lambda is : 5.244565470023357
# New model lambda is : 5.281865433274399
# Data beta is : 0.474
# Old model beta is : 0.42113309853863384
# New model beta is : 0.4049204196317388
# Le delta de likelihood vaut : -1.5760962878324491
# Le a tiré : 0.609944799488
# Le ratio de likelihood : 0.2067807371701821
# False
# Jump not accepted.

# %% [markdown]
# # Analysis and interpretation

# %%
def fetch_parameter_trace(i, parameters_trace):
    ar = []
    for p in parameters_trace:
        ar.append(p[i])
    return ar

likelihoods = ana.trace_likelihood

# %% [markdown]
# ### Acceptance rate

# %%
print("Acceptance rate is : " + str(ana.accepted_count/(1.*n)))
# Out:
# Acceptance rate is : 0.52

# %% [markdown]
# ### Likelihood through iterations

# %%
plt.plot(likelihoods[1:])
plt.xlabel('Iteration')
plt.ylabel('$log(L)$')
plt.title('Evolution of $log(L)$ through iterations')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-af8af9b821a3> in <module>()
# ----> 1 plt.plot(likelihoods[1:])
#       2 plt.xlabel('Iteration')
#       3 plt.ylabel('$log(L)$')
#       4 plt.title('Evolution of $log(L)$ through iterations')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## For $\lambda$ : ecliptical longitude

# %%
lambdas = fetch_parameter_trace(3, ana.trace_parameters)

# %% [markdown]
# ### Scatter plot : likelihood -vs- lambdas

# %%
plt.scatter(lambdas[1:], likelihoods[1:])
plt.title('$log(L)=f(\lambda)$')
plt.xlabel('$\lambda$')
plt.ylabel('$log(L)$')

# %% [markdown]
# ### $\lambda$ as a function of time

# %%
plt.plot(lambdas) 
plt.axhline(y=lamb) # plots horizontal key line
plt.xlabel('Iteration')
plt.ylabel('$\lambda$')
plt.title('Evolution of $\lambda$ through iterations')

# %% [markdown]
# ### Histogram of $\lambda$ : with automatic box binning

# %%
def stat_analysis(par_trace):
    mean = np.mean(par_trace)
    sigma = np.sqrt(np.var(par_trace))
    hist, bin_edges = np.histogram(par_trace)
    mode = (bin_edges[np.argmax(hist)] + bin_edges[np.argmax(hist)])/2  # middle of bin
    return mean, sigma, mode

plt.hist(lambdas, bins='auto', color='grey')
plt.xlabel('Value of $\lambda$')
plt.ylabel('Number of occurences')
plt.title('$\lambda$ posterior distribution')

# Add vertical line at $\lambda_{key}$
plt.axvline(x=lamb, color='r', label='$\lambda_{key}$')

lambda_mean, lambda_sigma, lambda_mode_edges = stat_analysis(lambdas)


# Add vertical line at $E(\lambda)$
plt.axvline(x=lambda_mean, label='$\mu_{\lambda}$')
plt.axvline(x=lambda_mean+lambda_sigma, color='g', label='$\mu_{\lambda}$+$\sigma_{\lambda}$' )
plt.axvline(x=lambda_mean-lambda_sigma, color='g', label='$\mu_{\lambda}$-$\sigma_{\lambda}$' )
plt.legend()

# %% [markdown]
# ## For $\beta$ : ecliptical latitude

# %%
betas = fetch_parameter_trace(2, ana.trace_parameters)

# %% [markdown]
# ### Scatter plot : log-likelihood -vs- beta

# %%
plt.scatter(betas[1:], likelihoods[1:])
plt.title(r'$log(L)=f(\beta)$')
plt.xlabel(r'$\beta$')
plt.ylabel('$log(L)$')

# %% [markdown]
# ### $\beta$ as a function of time

# %%
plt.plot(betas)
plt.axhline(y=beta) # plots horizontal key line
plt.xlabel('Iteration')
plt.ylabel(r'$\beta$')
plt.title(r'Evolution of $\beta$ through iterations')

# %% [markdown]
# ### Histogram of $\beta$ : automatic box binning

# %%
plt.hist(betas, bins='auto', color='grey')
plt.xlabel('Value of $\beta$')
plt.ylabel('Number of occurences')
plt.title(r'$\beta$ posterior distribution')

# Add vertical line at $\beta_{key}$
plt.axvline(x=beta, color='r', label=r'$\beta_{key}$')

beta_mean, beta_sigma, beta_mode_edges = stat_analysis(betas)


# Add vertical line at $E(\beta)$
plt.axvline(x=beta_mean, label=r'$\mu_{\beta}$')
plt.axvline(x=beta_mean+beta_sigma, color='g', label=r'$\mu_{\beta}$+$\sigma_{\beta}$' )
plt.axvline(x=beta_mean-beta_sigma, color='g', label=r'$\mu_{\beta}$-$\sigma_{\beta}$' )
plt.legend()

# %% [markdown]
# ## For $\omega$

# %%
omegas = fetch_parameter_trace(0, ana.trace_parameters)

# %% [markdown]
# ### Scatter plot : log-likelihood -vs- $\omega$

# %%
plt.scatter(omegas[1:], likelihoods[1:])
plt.title('$log(L)=f(\omega)$')
plt.xlabel('$\omega$')
plt.ylabel('$log(L)$')

# %% [markdown]
# ### $\omega$ as a function of time

# %%
plt.plot(omegas)
plt.axhline(y=omega) # plots horizontal key line
plt.xlabel('Iteration')
plt.ylabel('$\omega$')
plt.title('Evolution of $\omega$ through iterations')

# %% [markdown]
# ### Histogram of $\omega$ : automatic box binning

# %%
plt.hist(omegas, bins='auto', color='grey')
plt.xlabel('Value of $\omega$')
plt.ylabel('Number of occurences')
plt.title('$\omega$ posterior distribution')

# Add vertical line at $\omega_{key}$
plt.axvline(x=omega, color='r', label='$\omega_{key}$')

omega_mean, omega_sigma, omega_mode_edges = stat_analysis(omegas)


# Add vertical line at $E(\omega)$
plt.axvline(x=omega_mean, label='$\mu_{\omega}$')
plt.axvline(x=omega_mean+omega_sigma, color='g', label='$\mu_{\omega}$+$\sigma_{\omega}$' )
plt.axvline(x=omega_mean-omega_sigma, color='g', label='$\mu_{\omega}$-$\sigma_{\omega}$' )
plt.legend()
